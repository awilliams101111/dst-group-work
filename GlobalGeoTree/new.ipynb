# %%
import tarfile
import json
import pandas as pd

tar_path = "GlobalGeoTree-6M/GlobalGeoTree-6M/GGT-0.2M_0.5M-000000.tar"

small_sample = []

with tarfile.open(tar_path, "r") as tar:
    for member in tar:
        if member.isfile() and member.name.endswith(".json"):
            f = tar.extractfile(member)
            if f:
                obj = json.loads(f.read().decode("utf-8"))
                small_sample.append(obj)

                if len(small_sample) >= 1000:
                    break

df = pd.DataFrame(small_sample)
print(df.head())
print(df.shape)
# Out:
#    sample_id  longitude  latitude  elevation  slope  aspect  \
# 0   200001.0 -52.374358  4.802483       10.0    4.0    27.0
# 1        NaN        NaN       NaN        NaN    NaN     NaN
# 2   200002.0 -52.327230  4.844073       11.0    1.0    90.0
# 3        NaN        NaN       NaN        NaN    NaN     NaN
# 4   200003.0 -52.365163  4.802657       15.0    6.0   162.0
#
#    soil_moisture_0_5cm  soil_moisture_5_15cm  soil_moisture_15_30cm  bio01  \
# 0                193.0                 191.0                  191.0  264.0
# 1                  NaN                   NaN                    NaN    NaN
# 2                198.0                 198.0                  196.0  265.0
# 3                  NaN                   NaN                    NaN    NaN
# 4                  NaN                   NaN                    NaN  265.0
#
#    ...  bio14  bio15   bio16  bio17  bio18   bio19               level0  \
# 0  ...   68.0   50.0  1413.0  288.0  301.0  1086.0                  NaN
# 1  ...    NaN    NaN     NaN    NaN    NaN     NaN  Deciduous Broadleaf
# 2  ...   67.0   51.0  1373.0  276.0  286.0  1045.0                  NaN
# 3  ...    NaN    NaN     NaN    NaN    NaN     NaN  Deciduous Broadleaf
# 4  ...   70.0   50.0  1415.0  290.0  306.0  1111.0                  NaN
#
#    level1_family  level2_genus    level3_species
# 0            NaN           NaN               NaN
# 1      Cornaceae        Cornus  Cornus acuminata
# 2            NaN           NaN               NaN
# 3      Cornaceae        Cornus  Cornus acuminata
# 4            NaN           NaN               NaN
#
# [5 rows x 32 columns]
# (1000, 32)

# %%
# Out:
# True
